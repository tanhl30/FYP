# %%
import pandas as pd
import numpy as np
import fyp_functions as fyp
import matplotlib.pyplot as plt
import itertools

# %%
P = fyp.generate_random_preferences(9,2,2)

P = np.array([[0.86, 0.14],
       [0.77, 0.23],
       [0.85, 0.15],
       [0.94, 0.06],
       [0.02, 0.98],
       [0.77, 0.23],
       [0.56, 0.44],
       [0.67, 0.33],
       [0.5 , 0.5 ]])

df = fyp.iterate_over_alphas(P, 20, disutility_type='util')

fig, ax = plt.subplots(figsize=(7, 6))
ax.plot(df['alpha'],df['util'],marker=    'o',color='blue')
        
ax.set_title('Welfare Tradeoff')
ax.set_ylabel('Welfare')
ax.set_xlabel('Alpha')
ax.grid(True)
plt.tight_layout()
plt.show()
df
# Out:
#        alpha                                 allocation      util
# 0   0.000000   [0.6666666716337204, 0.3333333358168602]  3.560000
# 1   0.052632   [0.6721052678635245, 0.3278947391949202]  3.535789
# 2   0.105263  [0.6775438640933288, 0.32245614257298016]  3.524912
# 3   0.157895  [0.6829824603231329, 0.31701754595104015]  3.514035
# 4   0.210526  [0.6884210565529372, 0.31157894932910013]  3.503158
# 5   0.263158  [0.6938596527827414, 0.30614035270716017]  3.492281
# 6   0.315789  [0.6992982490125456, 0.30070175608522015]  3.481404
# 7   0.368421  [0.7047368452423497, 0.29526315946328013]  3.470526
# 8   0.421053    [0.710175441472154, 0.2898245628413401]  3.459649
# 9   0.473684  [0.7156140377019582, 0.28438596621940015]  3.448772
# 10  0.526316   [0.7210526339317622, 0.2789473695974601]  3.437895
# 11  0.578947   [0.7264912301615665, 0.2735087729755201]  3.427018
# 12  0.631579   [0.7319298263913707, 0.2680701763535801]  3.416140
# 13  0.684211    [0.737368422621175, 0.2626315797316401]  3.405263
# 14  0.736842   [0.742807018850979, 0.25719298310970007]  3.394386
# 15  0.789474  [0.7482456150807832, 0.25175438648776005]  3.383509
# 16  0.842105  [0.7536842113105874, 0.24631578986582003]  3.372632
# 17  0.894737  [0.7591228075403916, 0.24087719324388004]  3.361754
# 18  0.947368  [0.7645614037701958, 0.23543859662194003]  3.350877
# 19  1.000000                               [0.77, 0.23]  3.340000

# %%
a=.86
b=.76
c=.85
d=.94
e=.02
f=.77
g=.56
#h = 
#i = 


P=np.array([
       [a, 1-a],
       [b, 1-b],
       [c, 1-c],
       [d, 1-d],
       [e, 1-e],
       [f, 1-f],
       [g, 1-g],
#       [h, 1-h],
#       [i, 1-i]
       ])


df = fyp.iterate_over_alphas(P, 11, disutility_type='util')

fig, ax = plt.subplots(figsize=(7, 6))
ax.plot(df['alpha'],df['util'])
        
ax.set_title('Welfare Tradeoff')
ax.set_ylabel('Welfare')
ax.set_xlabel('Alpha')
ax.grid(True)
plt.tight_layout()
plt.show()
df
# Out:
#     alpha                                 allocation      util
# 0     0.0    [0.714285708963871, 0.2857142835855484]  2.914286
# 1     0.1   [0.7198571380674839, 0.2801428552269936]  2.880857
# 2     0.2   [0.7254285671710968, 0.2745714268684387]  2.847429
# 3     0.3   [0.7309999962747097, 0.2689999985098839]  2.814000
# 4     0.4  [0.7365714253783227, 0.26342857015132903]  2.780571
# 5     0.5   [0.7421428544819355, 0.2578571417927742]  2.747143
# 6     0.6  [0.7477142835855484, 0.25228571343421935]  2.713714
# 7     0.7   [0.7532857126891612, 0.2467142850756645]  2.680286
# 8     0.8  [0.7588571417927743, 0.24114285671710967]  2.646857
# 9     0.9  [0.7644285708963872, 0.23557142835855482]  2.631143
# 10    1.0                [0.77, 0.22999999999999998]  2.620000

# %%
# profile where allocation are unequal at n=4
P = np.array(	[[0.17, 0.83], [0.07, 0.93], [0.51, 0.49],[0.23,0.77]]	)
P = np.array(	[[0.8, 0.2], [0.9, 0.1], [0.87, 0.13],[0.75,0.25]]	)

# %%
#profile where welfare tradeoff have bend at n=7
P=np.array([[0.86, 0.14],
       [0.76, 0.24],
       [0.85, 0.15],
       [0.94, 0.06],
       [0.02, 0.98],
       [0.77, 0.23],
       [0.56, 0.44]])

# %%
#profile where welfare tradeoff have bend at n=9
P = np.array([[0.86, 0.14],
       [0.77, 0.23],
       [0.85, 0.15],
       [0.94, 0.06],
       [0.02, 0.98],
       [0.77, 0.23],
       [0.56, 0.44],
       [0.67, 0.33],
       [0.5 , 0.5 ]])

P=np.array([[0.16, 0.84],
       [0.25, 0.75],
       [0.33, 0.67],
       [0.75, 0.25],
       [0.54, 0.46],
       [0.03, 0.97],
       [0.05, 0.95],
       [0.16, 0.84],
       [0.42, 0.58]])

P= np.array([[0.87, 0.13],
       [0.47, 0.53],
       [0.73, 0.27],
       [0.98, 0.02],
       [0.41, 0.59],
       [0.69, 0.31],
       [0.47, 0.53],
       [0.87, 0.13],
       [0.78, 0.22]])

# %%
#profile where welfare tradeoff have bend at n=11
P = np.array([[0.33, 0.67],
       [0.27, 0.73],
       [0.32, 0.68],
       [0.3 , 0.7 ],
       [0.57, 0.43],
       [0.31, 0.69],
       [0.42, 0.58],
       [0.4 , 0.6 ],
       [0.26, 0.74],
       [0.32, 0.68],
       [0.88, 0.12]])

# %%
fyp.plot_vertical_allocation(P,True)
