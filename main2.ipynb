# %%
import pandas as pd
import numpy as np
import fyp_functions as fyp
import matplotlib.pyplot as plt
import itertools

# %%
P = fyp.generate_random_preferences(7, 2,2)
df = fyp.iterate_over_alphas(9, 2, P, 20, disutility_type='util')

fig, ax = plt.subplots(figsize=(7, 6))
ax.plot(df['alpha'],df['disutility'],marker ='o')
        
ax.set_title('Welfare Tradeoff')
ax.set_ylabel('Welfare')
ax.set_xlabel('Alpha')
ax.grid(True)
plt.tight_layout()
plt.show()

# %%
P
# Out:
# array([[0.38, 0.62],
#        [0.33, 0.67],
#        [0.67, 0.33],
#        [0.14, 0.86],
#        [0.61, 0.39],
#        [0.44, 0.56],
#        [0.39, 0.61]])

# %%
P
# Out:
# array([[0.38, 0.62],
#        [0.33, 0.67],
#        [0.67, 0.33],
#        [0.14, 0.86],
#        [0.61, 0.39],
#        [0.44, 0.56],
#        [0.39, 0.61]])

# %%
P
# Out:
# array([[0.38, 0.62],
#        [0.33, 0.67],
#        [0.67, 0.33],
#        [0.14, 0.86],
#        [0.61, 0.39],
#        [0.44, 0.56],
#        [0.39, 0.61]])
